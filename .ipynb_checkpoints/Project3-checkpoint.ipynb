# %%
#to enable visualizations 
# %matplotlib inline

# First, import pandas, a useful data analysis tool especially when working with labeled data
import pandas as pd

# import seaborn, visualization library in python 
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)

# Next, we'll load the cereal dataset, which is in the specified directory below
chicagocrime = pd.read_csv("C:\\Users\\oddin\\Desktop\\Project3\\\\project3\\chicagocrime.csv")

# Next, display the first 20 rows and all columns of the iris dataframe, good way to see the colum headings for the dataset
chicagocrime.head(10)
# Out:
#          ID Case Number  Year                       Block  IUCR  \
# 0   9878952    HX529642  2014             010XX E 47TH ST   497
# 1   2514319    HH857213  2002       055XX W CONGRESS PKWY  1320
# 2   3891396    HL266026  2005         050XX N KIMBALL AVE  141C
# 3   4983700    HM446634  2006         034XX W CHICAGO AVE  2092
# 4   5284225    HM654977  2006          007XX S CICERO AVE  1506
# 5   2182182    HH429064  2002         045XX N ASHLAND AVE  1811
# 6   2839797    HJ500224  2003       016XX N MAPLEWOOD AVE   620
# 7   7313423    HS117845  2010         015XX S SANGAMON ST   810
# 8  10374717    HZ110903  2015  050XX S WASHINGTON PARK CT  2820
# 9   3339646    HK381485  2004            001XX N STATE ST   860
#
#         Primary Type                                     Description  \
# 0            BATTERY  AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON
# 1    CRIMINAL DAMAGE                                      TO VEHICLE
# 2  WEAPONS VIOLATION                  UNLAWFUL USE OTHER DANG WEAPON
# 3          NARCOTICS                  SOLICIT NARCOTICS ON PUBLICWAY
# 4       PROSTITUTION                           SOLICIT ON PUBLIC WAY
# 5          NARCOTICS                    POSS: CANNABIS 30GMS OR LESS
# 6           BURGLARY                                  UNLAWFUL ENTRY
# 7              THEFT                                       OVER $500
# 8      OTHER OFFENSE                                TELEPHONE THREAT
# 9              THEFT                                    RETAIL THEFT
#
#       Location Description  Arrest  Domestic           ...             Ward  \
# 0                APARTMENT   False      True           ...              4.0
# 1                    OTHER   False      True           ...             29.0
# 2  SCHOOL, PUBLIC, GROUNDS    True     False           ...             39.0
# 3                 SIDEWALK    True     False           ...             27.0
# 4                   STREET    True     False           ...             24.0
# 5                   STREET    True     False           ...             47.0
# 6            PARK PROPERTY   False     False           ...              1.0
# 7                   STREET   False     False           ...             25.0
# 8                APARTMENT   False     False           ...              3.0
# 9         DEPARTMENT STORE    True     False           ...             42.0
#
#    Community Area  FBI Code  X Coordinate Y Coordinate  Year.1  \
# 0            39.0       04B     1183896.0    1874058.0    2014
# 1            25.0        14     1139530.0    1897135.0    2002
# 2            13.0        15     1152801.0    1933422.0    2005
# 3            23.0        26     1153483.0    1905125.0    2006
# 4            25.0        16     1144509.0    1896222.0    2006
# 5             3.0        18     1164839.0    1930205.0    2002
# 6            24.0         5     1159114.0    1910852.0    2003
# 7            28.0         6     1170443.0    1892718.0    2010
# 8            38.0        26           NaN          NaN    2015
# 9            32.0         6     1176352.0    1900927.0    2004
#
#         Updated On   Latitude  Longitude                 Location
# 0    2/4/2016 6:33  41.809597 -87.601016  (41.809597, -87.601016)
# 1   4/15/2016 8:55  41.873845 -87.763183  (41.873845, -87.763183)
# 2   4/15/2016 8:55  41.973168 -87.713495  (41.973168, -87.713495)
# 3   4/15/2016 8:55  41.895505 -87.711742  (41.895505, -87.711742)
# 4   4/15/2016 8:55  41.871248 -87.744926  (41.871248, -87.744926)
# 5   4/15/2016 8:55  41.964093 -87.669321  (41.964093, -87.669321)
# 6   4/15/2016 8:55  41.911107 -87.690903  (41.911107, -87.690903)
# 7    2/4/2016 6:33  41.861105 -87.649815  (41.861105, -87.649815)
# 8  1/15/2016 12:18        NaN        NaN                      NaN
# 9   4/15/2016 8:55  41.883500 -87.627877    (41.8835, -87.627877)
#
# [10 rows x 22 columns]

# %%
# to count the frequency of values for each primary crime type in the dataset
chicagocrime["Primary Type"].value_counts()
# Out:
# THEFT                               13015
# BATTERY                             11508
# CRIMINAL DAMAGE                      7215
# NARCOTICS                            6934
# OTHER OFFENSE                        3880
# ASSAULT                              3834
# BURGLARY                             3684
# MOTOR VEHICLE THEFT                  2927
# ROBBERY                              2338
# DECEPTIVE PRACTICE                   2320
# CRIMINAL TRESPASS                    1799
# PROSTITUTION                          654
# WEAPONS VIOLATION                     609
# PUBLIC PEACE VIOLATION                493
# OFFENSE INVOLVING CHILDREN            398
# CRIM SEXUAL ASSAULT                   238
# SEX OFFENSE                           224
# LIQUOR LAW VIOLATION                  178
# GAMBLING                              136
# INTERFERENCE WITH PUBLIC OFFICER      128
# ARSON                                 119
# HOMICIDE                               76
# KIDNAPPING                             54
# STALKING                               32
# INTIMIDATION                           30
# OBSCENITY                               7
# DOMESTIC VIOLENCE                       1
# NON-CRIMINAL                            1
# OTHER NARCOTIC VIOLATION                1
# Name: Primary Type, dtype: int64

# %%
#To create a pie chart showing primary crime types and years
fig,ax = plt.subplots(figsize=(12,12))
chicagocrime['Primary Type'].value_counts(sort=False).plot(kind='barh')
plt.title('Primary Crime Type and Community Area',fontsize=20)
plt.xlabel('Year',fontsize=16)
plt.ylabel('Primary Type',fontsize=16)

# %%
# To create a kdeplot which is a seaborn plot useful for looking at univariate relations 
# Creates and visualizes a kernel density estimate of the underlying feature

sns.FacetGrid(chicagocrime, hue="Primary Type", size=6) \
   .map(sns.kdeplot, "Year")\
   .add_legend()
