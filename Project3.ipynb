# %%
#to enable visualizations 
# %matplotlib inline

# First, import pandas, a useful data analysis tool especially when working with labeled data
import pandas as pd

import numpy as np
# import seaborn, visualization library in python 
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)
import datetime as dt

# %%
# Next, we'll load the cereal dataset, which is in the specified directory below
chicagocrime = pd.read_csv("C:\\Users\\oddin\\Desktop\\Project3\\\\project3\\chicagocrime.csv")

# Next, display the first 10 rows and all columns of the iris dataframe, good way to see the colum headings for the dataset
chicagocrime.head(10)
# Out:
#    Unnamed: 0        ID Case Number              Date  \
# 0     4506608   9878952    HX529642    12/4/2014 9:30
# 1      561379   2514319    HH857213   12/24/2002 9:00
# 2     5058884   3891396    HL266026   3/31/2005 11:46
# 3     3619502   4983700    HM446634   6/30/2006 16:44
# 4     5533749   5284225    HM654977  10/11/2006 23:05
# 5     6162396   2182182    HH429064     6/9/2002 5:00
# 6      720409   2839797    HJ500224   7/16/2003 17:45
# 7     2251410   7313423    HS117845   1/12/2010 22:30
# 8      557591  10374717    HZ110903   12/27/2015 2:13
# 9     4676604   3339646    HK381485   5/22/2004 19:07
#
#                         Block  IUCR       Primary Type  \
# 0             010XX E 47TH ST   497            BATTERY
# 1       055XX W CONGRESS PKWY  1320    CRIMINAL DAMAGE
# 2         050XX N KIMBALL AVE  141C  WEAPONS VIOLATION
# 3         034XX W CHICAGO AVE  2092          NARCOTICS
# 4          007XX S CICERO AVE  1506       PROSTITUTION
# ...

# %%
# to count the frequency of values for each primary crime type in the dataset from 2002 -2017
chicagocrime["Primary Type"].value_counts()
# Out:
# THEFT                               13015
# BATTERY                             11508
# CRIMINAL DAMAGE                      7215
# NARCOTICS                            6934
# OTHER OFFENSE                        3880
# ASSAULT                              3834
# BURGLARY                             3684
# MOTOR VEHICLE THEFT                  2927
# ROBBERY                              2338
# DECEPTIVE PRACTICE                   2320
# CRIMINAL TRESPASS                    1799
# PROSTITUTION                          654
# WEAPONS VIOLATION                     609
# PUBLIC PEACE VIOLATION                493
# OFFENSE INVOLVING CHILDREN            398
# CRIM SEXUAL ASSAULT                   238
# SEX OFFENSE                           224
# LIQUOR LAW VIOLATION                  178
# GAMBLING                              136
# INTERFERENCE WITH PUBLIC OFFICER      128
# ARSON                                 119
# HOMICIDE                               76
# ...

# %%
# to count the frequency of values for Arrests and non-arrests for the various crime types in the dataset from 2002 -2017
chicagocrime["Arrest"].value_counts()
# Out:
# False    44940
# True     17893
# Name: Arrest, dtype: int64

# %%
#To create a pie chart showing counts for the primary crime types 
fig,ax = plt.subplots(figsize=(12,12))
chicagocrime['Primary Type'].value_counts(sort=False).plot(kind='barh')
plt.title('Primary Crime Type Counts',fontsize=20)
plt.xlabel('Counts',fontsize=16)
plt.ylabel('Primary Type',fontsize=16)

# %%
# To create a kdeplot which is a seaborn plot useful for looking at univariate relations 
# Creates and visualizes a kernel density estimate of the underlying feature

sns.FacetGrid(chicagocrime, hue="Primary Type", size=6) \
   .map(sns.kdeplot, "Year")\
   .add_legend()

# %%
#use seaborn's FacetGrid to color the scatterplot by primary crime type
sns.FacetGrid(chicagocrime, hue="Primary Type", size=8) \
   .map(plt.scatter, "Community Area", "Ward") \
   .add_legend()

# %%
# Violin plot, unlike box plots, depict the density of the data
# Denser regions of the data are fatter, and sparser thiner in a violin plot
# further showing the distributions of the features 
sns.violinplot(x="Arrest", y="Year", data=chicagocrime, size=40)

# %%
m = Basemap(resolution='c',
            projection='kav7',
            lat_0=0., # Center around
            lon_0=0.) # lat 0, lon 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9416fa0daced> in <module>()
# ----> 1 m = Basemap(resolution='c',
#       2             projection='kav7',
#       3             lat_0=0., # Center around
#       4             lon_0=0.) # lat 0, lon 0
#
# NameError: name 'Basemap' is not defined

# %%
import pygal as pgl
from pygal.maps.world import World

# %%
map1=World()
map1.add(chicagocrime,(41.8095966,-87.60101633))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\oddin\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\Users\oddin\Anaconda3\lib\site-packages\pygal\graph\base.py in _repr_svg_(self)
#     228     def _repr_svg_(self):
#     229         """Display svg in IPython notebook"""
# --> 230         return self.render(disable_xml_declaration=True)
#     231
#     232     def _repr_png_(self):
#
# C:\Users\oddin\Anaconda3\lib\site-packages\pygal\graph\public.py in render(self, is_unicode, **kwargs)
#      50     def render(self, is_unicode=False, **kwargs):
#      51         """Render the graph, and return the svg string"""
# ...

# %%
sns.factorplot(data=chicagocrime,x='Year',y='Primary Type',col='Primary Type',col_wrap=4,size=2,kind='bar',aspect=2,saturation=2,
margin_titles=False)

# %%
fig1 = plt.figure(figsize=(16,20))
fig1.patch.set_facecolor('#e6e8ec')
ax = fig1.add_axes([0.1,0.1,0.8,0.8])

m.drawmapboundary(color='white', 
                  linewidth=0.0, 
                  fill_color='white')
m.drawparallels(parallels, 
                linewidth=lw, 
                dashes=dashes, 
                color=graticules_color)
m.drawmeridians(meridians, 
                linewidth=lw, 
                dashes=dashes, 
                color=graticules_color)
m.drawcoastlines(linewidth=0)
m.fillcontinents('black', 
                 lake_color='white')
m.drawcountries(linewidth=1, 
                linestyle='solid', 
                color='white', 
                zorder=30)

title = plt.title('World map (Kavrayskiy 7)', 
                  fontsize=20) 
title.set_y(1.03) # Move the title a bit for niceness
